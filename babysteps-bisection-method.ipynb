# %%
import matplotlib.pyplot as plt
import numpy as np


def f(x):
    return ((x**3) + x - 1)

x = np.linspace(0, 2, 51)

y = f(x)

plt.plot(x, y)

# %%
a = 0.0
b = 1.0
for i in range(20):
    print('%3d %15.10f %15.10f %15.10f %15.10f' %(i, a, f(a), b, f(b)))
    c = (a + b)/2
    if (f(a)*f(c) < 0):
        b = c
    else:
        a = c
# Out:
#   0    0.0000000000   -1.0000000000    1.0000000000    1.0000000000
#   1    0.5000000000   -0.3750000000    1.0000000000    1.0000000000
#   2    0.5000000000   -0.3750000000    0.7500000000    0.1718750000
#   3    0.6250000000   -0.1308593750    0.7500000000    0.1718750000
#   4    0.6250000000   -0.1308593750    0.6875000000    0.0124511719
#   5    0.6562500000   -0.0611267090    0.6875000000    0.0124511719
#   6    0.6718750000   -0.0248298645    0.6875000000    0.0124511719
#   7    0.6796875000   -0.0063138008    0.6875000000    0.0124511719
#   8    0.6796875000   -0.0063138008    0.6835937500    0.0030373931
#   9    0.6816406250   -0.0016460046    0.6835937500    0.0030373931
#  10    0.6816406250   -0.0016460046    0.6826171875    0.0006937413
#  11    0.6821289062   -0.0004766196    0.6826171875    0.0006937413
#  12    0.6821289062   -0.0004766196    0.6823730469    0.0001084388
#  13    0.6822509766   -0.0001841209    0.6823730469    0.0001084388
# ...
